# %% [markdown]
# <a href="https://colab.research.google.com/github/Edwin-svg/DeepTraining1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, time, random
import numpy as np
import pandas as pd
import cv2, torch
from tqdm.auto import tqdm
from PIL import Image
import shutil as sh

from IPython.display import Image, clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !unzip /content/data.zip -d /content/dataset/
# Out:
# Archive:  /content/data.zip
#    creating: /content/dataset/data/
#   inflating: /content/dataset/data/sample_submission.csv
#    creating: /content/dataset/data/testing_images/
#   inflating: /content/dataset/data/testing_images/vid_5_25100.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25120.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25140.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25160.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25180.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25200.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25220.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25240.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_25260.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_26320.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_26400.jpg
#   inflating: /content/dataset/data/testing_images/vid_5_26420.jpg
# ...

# %%
# %%time

# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U pycocotools
# !pip install -qr yolov5/requirements.txt  # install dependencies
# !cp yolov5/requirements.txt ./
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 15705 (delta 9), reused 15 (delta 3), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.45 MiB | 19.21 MiB/s, done.
# Resolving deltas: 100% (10755/10755), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# CPU times: user 96.7 ms, sys: 16.5 ms, total: 113 ms
# Wall time: 11.6 s

# %%
img_h, img_w, num_channels = (380, 676, 3)
df = pd.read_csv('/content/dataset/data/train_solution_bounding_boxes (1).csv')
df.rename(columns={'image':'image_id'}, inplace=True)
df['image_id'] = df['image_id'].apply(lambda x: x.split('.')[0])
df['x_center'] = (df['xmin'] + df['xmax'])/2
df['y_center'] = (df['ymin'] + df['ymax'])/2
df['w'] = df['xmax'] - df['xmin']
df['h'] = df['ymax'] - df['ymin']
df['classes'] = 0
df['x_center'] = df['x_center']/img_w
df['w'] = df['w']/img_w
df['y_center'] = df['y_center']/img_h
df['h'] = df['h']/img_h
df.head()
# Out:
#       image_id        xmin        ymin        xmax        ymax  x_center  \
# 0   vid_4_1000  281.259045  187.035071  327.727931  223.225547  0.450434
# 1  vid_4_10000   15.163531  187.035071  120.329957  236.430180  0.100217
# 2  vid_4_10040  239.192475  176.764801  361.968162  236.430180  0.444645
# 3  vid_4_10020  496.483358  172.363256  630.020260  231.539575  0.833213
# 4  vid_4_10060   16.630970  186.546010  132.558611  238.386422  0.110347
#
#    y_center         w         h  classes
# 0  0.539817  0.068741  0.095238        0
# 1  0.557191  0.155572  0.129987        0
# 2  0.543678  0.181621  0.157014        0
# 3  0.531451  0.197540  0.155727        0
# 4  0.559122  0.171491  0.136422        0

# %%
index = list(set(df.image_id))
image = random.choice(index)
print("Image ID: %s"%(image))
img = cv2.imread(f'/content/dataset/data/training_images/{image}.jpg')
img.shape
# Out:
# Image ID: vid_4_9740
# (380, 676, 3)

# %%
image = random.choice(index)
Image(filename=f'/content/dataset/data/training_images/{image}.jpg',width=600)

# %%
source = 'training_images'
if True:
    for fold in [0]:
        val_index = index[len(index)*fold//5:len(index)*(fold+1)//5]
        for name,mini in tqdm(df.groupby('image_id')):
            if name in val_index:
                path2save = 'val2017/'
            else:
                path2save = 'train2017/'
            if not os.path.exists('/tmp/convertor/fold{}/labels/'.format(fold)+path2save):
                os.makedirs('/tmp/convertor/fold{}/labels/'.format(fold)+path2save)
            with open('/tmp/convertor/fold{}/labels/'.format(fold)+path2save+name+".txt", 'w+') as f:
                row = mini[['classes','x_center','y_center','w','h']].astype(float).values
                row = row.astype(str)
                for j in range(len(row)):
                    text = ' '.join(row[j])
                    f.write(text)
                    f.write("\n")
            if not os.path.exists('/tmp/convertor/fold{}/images/{}'.format(fold,path2save)):
                os.makedirs('/tmp/convertor/fold{}/images/{}'.format(fold,path2save))
            sh.copy("/content/dataset/data/{}/{}.jpg".format(source,name),'/tmp/convertor/fold{}/images/{}/{}.jpg'.format(fold,path2save,name))
# Out:
#   0%|          | 0/355 [00:00<?, ?it/s]

# %%
#!python train.py --batch 2 --epochs 1 --data ../input/yolov5-config/car.yaml --cfg ../input/yolov5-config/yolov5x.yaml --name yolov5x_fold0_new

# %%
# !python yolov5/detect.py --weights yolov5/yolov5s.pt --img 676 --conf 0.4 --source /content/dataset/data/testing_images
# Out:
# detect: weights=['yolov5/yolov5s.pt'], source=/content/dataset/data/testing_images, data=yolov5/data/coco128.yaml, imgsz=[676, 676], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 256MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ --img-size [676, 676] must be multiple of max stride 32, updating to [704, 704]
# image 1/175 /content/dataset/data/testing_images/vid_5_25100.jpg: 416x704 (no detections), 255.0ms
# image 2/175 /content/dataset/data/testing_images/vid_5_25120.jpg: 416x704 (no detections), 225.6ms
# ...

# %%
predicted_files = []
for (dirpath, dirnames, filenames) in os.walk("/content/yolov5/runs/detect/exp"):
    predicted_files.extend(filenames)

# %%
Image(filename=f'/content/yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'/content/yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'/content/yolov5/runs/detect/exp/{random.choice(predicted_files)}')

# %%
Image(filename=f'/content/yolov5/runs/detect/exp/{random.choice(predicted_files)}')
